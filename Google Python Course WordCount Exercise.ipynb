# %%
#!/usr/bin/python -tt
# Copyright 2010 Google Inc.
# Licensed under the Apache License, Version 2.0
# http://www.apache.org/licenses/LICENSE-2.0

# Google's Python Class
# http://code.google.com/edu/languages/google-python-class/

"""Wordcount exercise
Google's Python class

The main() below is already defined and complete. It calls print_words()
and print_top() functions which you write.

1. For the --count flag, implement a print_words(filename) function that counts
how often each word appears in the text and prints:
word1 count1
word2 count2
...

Print the above list in order sorted by word (python will sort punctuation to
come before letters -- that's fine). Store all the words as lowercase,
so 'The' and 'the' count as the same word.

2. For the --topcount flag, implement a print_top(filename) which is similar
to print_words() but which prints just the top 20 most common words sorted
so the most common word is first, then the next most common, and so on.

Use str.split() (no arguments) to split on all whitespace.

Workflow: don't build the whole program at once. Get it to an intermediate
milestone and print your data structure and sys.exit(0).
When that's working, try for the next milestone.

Optional: define a helper function to avoid code duplication inside
print_words() and print_top().

"""

import sys

# +++your code here+++
# Define print_words(filename) and print_top(filename) functions.
# You could write a helper utility function that reads a file
# and builds and returns a word/count dict for it.
# Then print_words() and print_top() can just call the utility function.

###

# This basic command line argument parsing code is provided and
# calls the print_words() and print_top() functions which you must define.
def main():
  if len(sys.argv) != 3:
    print 'usage: ./wordcount.py {--count | --topcount} file'
    sys.exit(1)

  option = sys.argv[1]
  filename = sys.argv[2]
  if option == '--count':
    print_words(filename)
  elif option == '--topcount':
    print_top(filename)
  else:
    print 'unknown option: ' + option
    sys.exit(1)

if __name__ == '__main__':
  main()
# Out:
# unknown option: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
#example

# %%
def word_count_d(filename): #Lets make a dictionary of words with their counts.. unsorted for now 
  word_counts_d={} # word_counts_d is a dictionary , keys are words, values are their counts
  file_input = open(filename, 'r')
  for line in file_input:
    words=line.split()
    for word in words:
      word=word.lower()
      if not word in word_counts_d:
        word_counts_d[word]=1
      else: 
        word_counts_d[word]+=1
  return word_counts_d

# %%
#Example 
word_count('Google Python Course WordCount Exercise.ipynb')
# Out:
# {'!=': 1,
#  '"': 312,
#  '"#': 12,
#  '"#!/usr/bin/python': 1,
#  '"###\\n",': 1,
#  '"#example': 1,
#  '"#example\\n",': 1,
#  '"...\\n",': 1,
#  '".py",': 1,
#  '"1.': 1,
#  '"2.': 1,
#  '"2.7.10"': 1,
#  '"\\"\\"\\"\\n",': 1,
#  '"\\"\\"\\"wordcount': 1,
#  '"\\n"': 1,
#  '"\\n",': 16,
#  '"\\u001b---------------------------------------------------------------------------\\u001b",': 1,
#  '"\\u001bnameerror\\u001b': 1,
#  '"\\u001bnameerror\\u001b:': 1,
#  '"\\u001b<ipython-input-20-76a6cfaec8b6>\\u001b': 1,
#  '"\\u001b<ipython-input-21-d3b0c6164b29>\\u001b': 1,
#  '"and': 1,
#  '"cell_type":': 6,
#  '"cells":': 1,
#  '"code",': 6,
#  '"codemirror_mode":': 1,
#  '"come': 1,
#  '"data":': 1,
#  '"def': 3,
#  '"display_name":': 1,
#  '"ename":': 1,
#  '"error",': 1,
#  '"evalue":': 1,
#  '"execute_result"': 1,
#  '"execution_count":': 7,
#  '"file_extension":': 1,
#  '"global': 1,
#  '"google\'s': 1,
#  '"how': 1,
#  '"if': 1,
#  '"import': 1,
#  '"ipython",': 1,
#  '"ipython2",': 1,
#  '"kernelspec":': 1,
#  '"language":': 1,
#  '"language_info":': 1,
#  '"metadata":': 8,
#  '"milestone': 1,
#  '"mimetype":': 1,
#  '"name":': 3,
#  '"nameerror",': 1,
#  '"nbconvert_exporter":': 1,
#  '"nbformat":': 1,
#  '"nbformat_minor":': 1,
#  '"optional:': 1,
#  '"output_type":': 2,
#  '"outputs":': 6,
#  '"print': 1,
#  '"print_words(\'google': 1,
#  '"print_words()': 1,
#  '"pygments_lexer":': 1,
#  '"python': 1,
#  '"python",': 3,
#  '"python2"': 1,
#  '"so': 2,
#  '"source":': 6,
#  '"text/plain":': 1,
#  '"text/x-python",': 1,
#  '"the': 1,
#  '"to': 1,
#  '"traceback":': 1,
#  '"use': 1,
#  '"version":': 2,
#  '"when': 1,
#  '"word1': 1,
#  '"word2': 1,
#  '"word_count(\'google': 1,
#  '"workflow:': 1,
#  '"{\'!=\':': 1,
#  '#': 1,
#  '#lets': 1,
#  '#sorting': 1,
#  "'": 1,
#  "'#':": 1,
#  "'(no':": 1,
#  "'(python':": 1,
#  "'+':": 1,
#  "'+++your':": 1,
#  "',':": 1,
#  "'--':": 1,
#  "'--count':": 1,
#  '\'--count\':\\n",': 1,
#  "'--topcount':": 1,
#  '\'--topcount\':\\n",': 1,
#  "'--topcount}':": 1,
#  '\'-tt\\\\\\\\n\\",\':': 1,
#  "'./wordcount.py':": 1,
#  "'2':": 1,
#  '\'2.0\\\\\\\\n\\",\':': 1,
#  "'20':": 1,
#  "'2010':": 1,
#  '\'2\\",\':': 1,
#  '\'3:\\\\\\\\n\\",\':': 1,
#  "'4,':": 1,
#  "'9,':": 1,
#  "'=':": 1,
#  "'==':": 1,
#  "'[':": 1,
#  "'[],':": 1,
#  '\'\\"#!/usr/bin/python\':': 1,
#  '\'\\"###\\\\\\\\n\\",\':': 1,
#  '\'\\"#\':': 1,
#  '\'\\"#example\':': 1,
#  '\'\\"\':': 1,
#  '\'\\"...\\\\\\\\n\\",\':': 1,
#  '\'\\".py\\",\':': 1,
#  '\'\\"1.\':': 1,
#  '\'\\"2.\':': 1,
#  '\'\\"2.7.10\\"\':': 1,
#  '\'\\"\\\\\\\\\\"\\\\\\\\\\"\\\\\\\\\\"\\\\\\\\n\\",\':': 1,
#  '\'\\"\\\\\\\\\\"\\\\\\\\\\"\\\\\\\\\\"wordcount\':': 1,
#  '\'\\"\\\\\\\\n\\"\':': 1,
#  '\'\\"\\\\\\\\n\\",\':': 1,
#  '\'\\"and\':': 1,
#  '\'\\"cell_type\\":\':': 1,
#  '\'\\"cells\\":\':': 1,
#  '\'\\"code\\",\':': 1,
#  '\'\\"codemirror_mode\\":\':': 1,
#  '\'\\"come\':': 1,
#  '\'\\"def\':': 1,
#  '\'\\"display_name\\":\':': 1,
#  '\'\\"execution_count\\":\':': 1,
#  '\'\\"file_extension\\":\':': 1,
#  '\'\\"google\\\\\'s\':': 1,
#  '\'\\"how\':': 1,
#  '\'\\"if\':': 1,
#  '\'\\"import\':': 1,
#  '\'\\"ipython2\\",\':': 1,
#  '\'\\"ipython\\",\':': 1,
#  '\'\\"kernelspec\\":\':': 1,
#  '\'\\"language\\":\':': 1,
#  '\'\\"language_info\\":\':': 1,
#  '\'\\"metadata\\":\':': 1,
#  '\'\\"milestone\':': 1,
#  '\'\\"mimetype\\":\':': 1,
#  '\'\\"name\\":\':': 1,
#  '\'\\"nbconvert_exporter\\":\':': 1,
#  '\'\\"nbformat\\":\':': 1,
#  '\'\\"nbformat_minor\\":\':': 1,
#  '\'\\"optional:\':': 1,
#  '\'\\"outputs\\":\':': 1,
#  '\'\\"print\':': 1,
#  '\'\\"print_words()\':': 1,
#  '\'\\"pygments_lexer\\":\':': 1,
#  '\'\\"python\':': 1,
#  '\'\\"python2\\"\':': 1,
#  '\'\\"python\\",\':': 1,
#  '\'\\"so\':': 1,
#  '\'\\"source\\":\':': 1,
#  '\'\\"text/x-python\\",\':': 1,
#  '\'\\"the\':': 1,
#  '\'\\"to\':': 1,
#  '\'\\"use\':': 1,
#  '\'\\"version\\":\':': 1,
#  '\'\\"when\':': 1,
#  '\'\\"word1\':': 1,
#  '\'\\"word2\':': 1,
#  '\'\\"word_count(\\\\\'google\':': 1,
#  '\'\\"workflow:\':': 1,
#  '\'\\\\\'--count\\\\\':\\\\\\\\n\\",\':': 1,
#  '\'\\\\\'--topcount\\\\\':\\\\\\\\n\\",\':': 1,
#  '\'\\\\\'__main__\\\\\':\\\\\\\\n\\",\':': 1,
#  '\'\\\\\'r\\\\\')\\\\\\\\n\\",\':': 1,
#  '\'\\\\\\\\n\\",\':': 1,
#  "']':": 1,
#  "'],':": 1,
#  '\'__main__\':\\n",': 1,
#  "'__name__':": 1,
#  "'a':": 1,
#  "'above':": 1,
#  "'all':": 1,
#  "'already':": 1,
#  "'an':": 1,
#  "'and':": 1,
#  '\'and\\\\\\\\n\\",\':': 1,
#  "'apache':": 1,
#  "'appears':": 1,
#  "'are':": 1,
#  "'argument':": 1,
#  "'arguments)':": 1,
#  "'as':": 1,
#  "'at':": 1,
#  "'avoid':": 1,
#  "'basic':": 1,
#  "'before':": 1,
#  "'below':": 1,
#  "'build':": 1,
#  "'builds':": 1,
#  "'but':": 1,
#  "'by':": 1,
#  "'call':": 1,
#  "'calls':": 1,
#  "'can':": 1,
#  '\'class\\\\\\\\n\\",\':': 1,
#  "'code':": 1,
#  "'command':": 1,
#  "'common':": 1,
#  "'common,':": 1,
#  "'complete.':": 1,
#  "'copyright':": 1,
#  "'could':": 1,
#  "'count':": 1,
#  '\'count1\\\\\\\\n\\",\':': 1,
#  '\'count2\\\\\\\\n\\",\':': 1,
#  '\'counts\\\\\\\\n\\",\':': 1,
#  "'course':": 1,
#  "'data':": 1,
#  "'define':": 1,
#  '\'define.\\\\\\\\n\\",\':': 1,
#  "'defined':": 1,
#  "'dict':": 1,
#  "'dictionary':": 1,
#  "'duplication':": 1,
#  "'each':": 1,
#  "'elif':": 1,
#  "'else:':": 1,
#  '\'else:\\\\\\\\n\\",\':': 1,
#  '\'exercise.ip\\\\\')\\"\':': 1,
#  '\'exercise\\\\\\\\n\\",\':': 1,
#  '\'file\\\\\'\\\\\\\\n\\",\':': 1,
#  '\'file\\\\\\\\n\\",\':': 1,
#  "'file_input':": 1,
#  '\'file_input:\\\\\\\\n\\",\':': 1,
#  "'filename':": 1,
#  "'fine).':": 1,
#  "'first,':": 1,
#  "'flag,':": 1,
#  "'for':": 1,
#  "'function':": 1,
#  '\'function.\\\\\\\\n\\",\':': 1,
#  "'functions':": 1,
#  '\'functions.\\\\\\\\n\\",\':': 1,
#  "'get':": 1,
#  "'google':": 1,
#  "'helper':": 1,
#  '\'here+++\\\\\\\\n\\",\':': 1,
#  '\'http://code.google.com/edu/languages/google-python-class/\\\\\\\\n\\",\':': 1,
#  '\'http://www.apache.org/licenses/license-2.0\\\\\\\\n\\",\':': 1,
#  "'if':": 1,
#  "'implement':": 1,
#  "'in':": 1,
#  '\'inc.\\\\\\\\n\\",\':': 1,
#  '\'inside\\\\\\\\n\\",\':': 1,
#  '\'intermediate\\\\\\\\n\\",\':': 1,
#  "'is':": 1,
#  "'it':": 1,
#  '\'it.\\\\\\\\n\\",\':': 1,
#  "'just':": 1,
#  "'keys':": 1,
#  "'len(sys.argv)':": 1,
#  "'letters':": 1,
#  "'license,':": 1,
#  "'licensed':": 1,
#  "'line':": 1,
#  "'list':": 1,
#  '\'lowercase,\\\\\\\\n\\",\':': 1,
#  "'main()':": 1,
#  '\'main():\\\\\\\\n\\",\':': 1,
#  '\'main()\\\\\\\\n\\",\':': 1,
#  '\'milestone.\\\\\\\\n\\",\':': 1,
#  "'most':": 1,
#  "'must':": 1,
#  "'next':": 1,
#  "'not':": 1,
#  "'null,':": 1,
#  "'often':": 1,
#  "'on':": 1,
#  '\'on.\\\\\\\\n\\",\':': 1,
#  "'once.':": 1,
#  "'open(filename,':": 1,
#  "'option':": 1,
#  "'option:':": 1,
#  '\'option\\\\\\\\n\\",\':': 1,
#  "'order':": 1,
#  "'parsing':": 1,
#  "'print':": 1,
#  "'print_top()':": 1,
#  '\'print_top().\\\\\\\\n\\",\':': 1,
#  "'print_top(filename)':": 1,
#  '\'print_top(filename)\\\\\\\\n\\",\':': 1,
#  "'print_words()':": 1,
#  '\'print_words()\\\\\\\\n\\",\':': 1,
#  "'print_words(filename)':": 1,
#  '\'print_words(filename)\\\\\\\\n\\",\':': 1,
#  "'prints':": 1,
#  '\'prints:\\\\\\\\n\\",\':': 1,
#  "'program':": 1,
#  "'provided':": 1,
#  "'punctuation':": 1,
#  "'python':": 1,
#  '\'r\')\\n",': 1,
#  "'reads':": 1,
#  "'return':": 1,
#  "'returns':": 1,
#  "'same':": 1,
#  '\'similar\\\\\\\\n\\",\':': 1,
#  "'so':": 1,
#  "'sort':": 1,
#  "'sorted':": 1,
#  '\'sorted\\\\\\\\n\\",\':': 1,
#  "'split':": 1,
#  "'store':": 1,
#  "'str.split()':": 1,
#  "'structure':": 1,
#  '\'sys.argv[1]\\\\\\\\n\\",\':': 1,
#  '\'sys.argv[2]\\\\\\\\n\\",\':': 1,
#  '\'sys.exit(0).\\\\\\\\n\\",\':': 1,
#  '\'sys.exit(1)\\\\\\\\n\\",\':': 1,
#  '\'sys\\\\\\\\n\\",\':': 1,
#  "'text':": 1,
#  "'that':": 1,
#  "'the'": 2,
#  "'the':": 1,
#  "'their':": 1,
#  "'then':": 1,
#  "'this':": 1,
#  "'to':": 1,
#  '\'to\\\\\\\\n\\",\':': 1,
#  "'top':": 1,
#  "'try':": 1,
#  "'under':": 1,
#  "'unknown": 1,
#  "'usage:": 1,
#  "'utility':": 1,
#  "'values':": 1,
#  "'version':": 1,
#  "'which':": 1,
#  '\'whitespace.\\\\\\\\n\\",\':': 1,
#  "'whole':": 1,
#  "'will':": 1,
#  "'word':": 1,
#  '\'word.\\\\\\\\n\\",\':': 1,
#  "'word/count':": 1,
#  '\'word=lower.word()\\\\\\\\n\\",\':': 1,
#  '\'word_count(filename):\\\\\\\\n\\",\':': 1,
#  "'word_count_d'": 2,
#  "'word_counts_d':": 1,
#  '\'word_counts_d:\\\\\\\\n\\",\':': 1,
#  "'word_counts_d={}':": 1,
#  '\'word_counts_d[word]+=1\\\\\\\\n\\",\':': 1,
#  '\'word_counts_d[word]=1\\\\\\\\n\\",\':': 1,
#  '\'word_counts_d\\"\':': 1,
#  "'wordcount':": 1,
#  "'words':": 1,
#  "'words,':": 1,
#  '\'words:\\\\\\\\n\\",\':': 1,
#  '\'words=line.split()\\\\\\\\n\\",\':': 1,
#  "'working,':": 1,
#  "'write':": 1,
#  '\'write.\\\\\\\\n\\",\':': 1,
#  "'you':": 1,
#  "'your':": 1,
#  "'{':": 1,
#  "'{--count':": 1,
#  "'{},':": 1,
#  "'|':": 1,
#  "'}':": 1,
#  "'},':": 1,
#  '(most': 1,
#  '(no': 1,
#  '(python': 1,
#  '+': 1,
#  '+++your': 1,
#  ',': 1,
#  '--': 1,
#  '--count': 1,
#  '--topcount': 1,
#  '--topcount}': 1,
#  '-tt\\n",': 1,
#  './wordcount.py': 1,
#  '1,\\n",': 215,
#  '11,': 1,
#  '12,': 2,
#  '12,\\n",': 2,
#  '14,\\n",': 1,
#  '16,\\n",': 1,
#  '1\\u001b': 2,
#  '2': 2,
#  '2",': 1,
#  '2,\\n",': 31,
#  '2.0\\n",': 1,
#  '20': 1,
#  '20,': 1,
#  '2010': 1,
#  '21,': 1,
#  '24,\\n",': 1,
#  '2\\u001b': 2,
#  '3,\\n",': 24,
#  '3:\\n",': 1,
#  '3\\u001b': 1,
#  '4,': 1,
#  '4,\\n",': 3,
#  '4\\u001b': 1,
#  '5,\\n",': 3,
#  '5\\u001b': 1,
#  '5}"': 1,
#  '6,\\n",': 1,
#  '7,\\n",': 1,
#  '8,\\n",': 1,
#  '=': 3,
#  '==': 3,
#  '[': 10,
#  '[]': 1,
#  '[],': 4,
#  '\\"\'\\":': 1,
#  '\\"\'the\'\\":': 1,
#  '\\"\'unknown\\":': 1,
#  '\\"\'usage:\\":': 1,
#  '\\"don\'t\\":': 1,
#  '\\"google\'s\\":': 1,
#  '\\"that\'s\\":': 1,
#  '\\n",': 4,
#  '\\u001b#example\\u001b\\u001b\\u001b\\u001b\\u001b\\u001b\\n\\u001b---->': 1,
#  '\\u001b#sorting': 1,
#  '\\u001bdef\\u001b': 1,
#  '\\u001bfor\\u001b': 1,
#  '\\u001bin\\u001b': 1,
#  '\\u001bprint\\u001b\\u001b(\\u001b\\u001bword\\u001b\\u001b,\\u001b\\u001bwords_dict\\u001b\\u001b[\\u001b\\u001bword\\u001b\\u001b[0;34m]\\u001b\\u001b)\\u001b\\u001b\\u001b\\u001b\\n",': 1,
#  '\\u001b<module>\\u001b()\\u001b\\n\\u001b': 1,
#  '\\u001bprint_words\\u001b(filename)\\u001b\\n\\u001b': 1,
#  "\\u001bprint_words\\u001b\\u001b(\\u001b\\u001b'google": 1,
#  '\\u001bprint_words\\u001b\\u001b(\\u001b\\u001bfilename\\u001b\\u001b)\\u001b\\u001b:\\u001b\\u001b\\u001b\\u001b\\n\\u001b---->': 1,
#  '\\u001bword\\u001b': 1,
#  '\\u001bword_count_d\\u001b\\u001b(\\u001b\\u001bfilename\\u001b\\u001b)\\u001b': 1,
#  '\\u001bwords\\u001b\\u001b:\\u001b\\u001b\\u001b\\u001b\\n\\u001b': 1,
#  '\\u001bwords\\u001b\\u001b=\\u001b\\u001bsorted\\u001b\\u001b(\\u001b\\u001bwords_dict\\u001b\\u001b.\\u001b\\u001bkeys\\u001b\\u001b(\\u001b\\u001b)\\u001b\\u001b)\\u001b\\u001b\\u001b\\u001b\\n\\u001b': 1,
#  '\\u001bwords_dict\\u001b\\u001b=\\u001b': 1,
#  ']': 7,
#  '],': 3,
#  '__name__': 1,
#  'a': 8,
#  'above': 1,
#  'all': 2,
#  'already': 1,
#  'an': 1,
#  'and': 12,
#  'and\\n",': 1,
#  'apache': 1,
#  'appears': 1,
#  'are': 4,
#  'argument': 1,
#  'arguments)': 1,
#  'as': 2,
#  'at': 1,
#  'avoid': 1,
#  'basic': 1,
#  'before': 1,
#  'below': 1,
#  'build': 1,
#  'builds': 1,
#  'but': 1,
#  'by': 1,
#  'call': 2,
#  'calls': 2,
#  'can': 1,
#  'class\\n",': 2,
#  'code': 3,
#  'command': 1,
#  'common': 2,
#  'common,': 1,
#  'complete.': 1,
#  'copyright': 1,
#  'could': 1,
#  'count': 1,
#  'count1\\n",': 1,
#  'count2\\n",': 1,
#  'counts..': 1,
#  'counts\\n",': 2,
#  'course': 3,
#  'data': 1,
#  'define': 2,
#  'define.\\n",': 1,
#  'defined': 1,
#  'defined"': 1,
#  'defined",': 1,
#  'dict': 1,
#  'dictionary': 2,
#  "don't": 1,
#  'duplication': 1,
#  'each': 1,
#  'elif': 1,
#  'else:': 1,
#  'else:\\n",': 1,
#  'exercise.ipynb\')"': 2,
#  'exercise.ipynb\'\\u001b\\u001b)\\u001b\\u001b\\u001b\\u001b\\n\\u001b",': 1,
#  'exercise\\n",': 1,
#  'file\'\\n",': 1,
#  'file\\n",': 1,
#  'file_input': 1,
#  'file_input:\\n",': 1,
#  'filename': 1,
#  'fine).': 1,
#  'first,': 1,
#  'flag,': 2,
#  'for': 8,
#  'function': 3,
#  'function.\\n",': 1,
#  'functions': 2,
#  'functions.\\n",': 1,
#  'get': 1,
#  'global': 1,
#  'google': 1,
#  "google's": 1,
#  'helper': 2,
#  'here+++\\n",': 1,
#  'http://code.google.com/edu/languages/google-python-class/\\n",': 1,
#  'http://www.apache.org/licenses/license-2.0\\n",': 1,
#  'if': 3,
#  'implement': 2,
#  'in': 8,
#  'inc.\\n",': 1,
#  'inside\\n",': 1,
#  'intermediate\\n",': 1,
#  'is': 7,
#  'it': 2,
#  'it.\\n",': 1,
#  'just': 2,
#  'keys': 3,
#  'last)",': 1,
#  'len(sys.argv)': 1,
#  'letters': 1,
#  'license,': 1,
#  'licensed': 1,
#  'line': 2,
#  'list': 1,
#  'lowercase,\\n",': 1,
#  'main()': 1,
#  'main():\\n",': 1,
#  'main()\\n",': 1,
#  'make': 1,
#  'milestone.\\n",': 1,
#  'most': 3,
#  'must': 1,
#  'name': 2,
#  'next': 2,
#  'not': 3,
#  'now': 1,
#  'null,': 2,
#  'of': 1,
#  'often': 1,
#  'on': 1,
#  'on.\\n",': 1,
#  'once.': 1,
#  'open(filename,': 1,
#  'option': 3,
#  'option:': 1,
#  'option\\n",': 1,
#  'order': 1,
#  'parsing': 1,
#  'print': 3,
#  'print(word,words_dict[word])"': 1,
#  'print_top()': 3,
#  'print_top().\\n",': 1,
#  'print_top(filename)': 2,
#  'print_top(filename)\\n",': 1,
#  'print_words()': 3,
#  'print_words()\\n",': 1,
#  'print_words(filename)': 2,
#  'print_words(filename):\\n",': 1,
#  'print_words(filename)\\n",': 1,
#  'prints': 1,
#  'prints:\\n",': 1,
#  'program': 1,
#  'provided': 1,
#  'punctuation': 1,
#  'python': 5,
#  'reads': 1,
#  'recent': 1,
#  'return': 1,
#  'returns': 1,
#  'same': 1,
#  'similar\\n",': 1,
#  'so': 1,
#  'sort': 1,
#  'sorted': 1,
#  'sorted\\n",': 1,
#  'split': 1,
#  'store': 1,
#  'str.split()': 1,
#  'structure': 1,
#  'sys.argv[1]\\n",': 1,
#  'sys.argv[2]\\n",': 1,
#  'sys.exit(0).\\n",': 1,
#  'sys.exit(1)\\n",': 2,
#  'sys\\n",': 1,
#  'text': 1,
#  'that': 2,
#  "that's": 2,
#  'the': 14,
#  'their': 2,
#  'then': 2,
#  'this': 1,
#  'to': 3,
#  'to\\n",': 1,
#  'top': 1,
#  'traceback': 1,
#  'try': 1,
#  'under': 1,
#  'unsorted': 1,
#  'utility': 2,
#  'values': 1,
#  'version': 1,
#  'which': 6,
#  'whitespace.\\n",': 1,
#  'whole': 1,
#  'will': 1,
#  'with': 1,
#  'word': 6,
#  'word.\\n",': 1,
#  'word/count': 1,
#  'word=word.lower()\\n",': 1,
#  'word_count_d(filename)': 1,
#  'word_count_d(filename):': 1,
#  'word_counts_d': 1,
#  'word_counts_d"': 1,
#  'word_counts_d:\\n",': 1,
#  'word_counts_d={}': 1,
#  'word_counts_d[word]+=1\\n",': 1,
#  'word_counts_d[word]=1\\n",': 1,
#  'wordcount': 3,
#  'words': 4,
#  'words,': 1,
#  'words:\\n",': 2,
#  'words=line.split()\\n",': 1,
#  'words=sorted(words_dict.keys())\\n",': 1,
#  'words\\u001b\\u001b\\u001b\\u001b\\n\\u001b\\u001b': 1,
#  'words_dict=': 1,
#  'working,': 1,
#  'write': 1,
#  'write.\\n",': 1,
#  'you': 3,
#  'your': 1,
#  '{': 14,
#  '{--count': 1,
#  '{},': 7,
#  '|': 1,
#  '}': 5,
#  '},': 9}

# %%
def print_words(filename):
  words_dict= word_count_d(filename) #Sorting keys which are words 
  words=sorted(words_dict.keys())
  for word in words:
    print(word,words_dict[word])

# %%
#Example
print_words('Google Python Course WordCount Exercise.ipynb')
# Out:
# ('!=', 1)
# ('"', 312)
# ('"#', 12)
# ('"#!/usr/bin/python', 1)
# ('"###\\n",', 1)
# ('"#example', 1)
# ('"#example\\n",', 1)
# ('"...\\n",', 1)
# ('".py",', 1)
# ('"1.', 1)
# ('"2.', 1)
# ('"2.7.10"', 1)
# ('"\\"\\"\\"\\n",', 1)
# ('"\\"\\"\\"wordcount', 1)
# ('"\\n"', 1)
# ('"\\n",', 16)
# ('"\\u001b---------------------------------------------------------------------------\\u001b",', 1)
# ('"\\u001bnameerror\\u001b', 1)
# ('"\\u001bnameerror\\u001b:', 1)
# ('"\\u001b<ipython-input-20-76a6cfaec8b6>\\u001b', 1)
# ('"\\u001b<ipython-input-21-d3b0c6164b29>\\u001b', 1)
# ('"and', 1)
# ('"cell_type":', 6)
# ('"cells":', 1)
# ('"code",', 6)
# ('"codemirror_mode":', 1)
# ('"come', 1)
# ('"data":', 1)
# ('"def', 3)
# ('"display_name":', 1)
# ('"ename":', 1)
# ('"error",', 1)
# ('"evalue":', 1)
# ('"execute_result"', 1)
# ('"execution_count":', 7)
# ('"file_extension":', 1)
# ('"global', 1)
# ('"google\'s', 1)
# ('"how', 1)
# ('"if', 1)
# ('"import', 1)
# ('"ipython",', 1)
# ('"ipython2",', 1)
# ('"kernelspec":', 1)
# ('"language":', 1)
# ('"language_info":', 1)
# ('"metadata":', 8)
# ('"milestone', 1)
# ('"mimetype":', 1)
# ('"name":', 3)
# ('"nameerror",', 1)
# ('"nbconvert_exporter":', 1)
# ('"nbformat":', 1)
# ('"nbformat_minor":', 1)
# ('"optional:', 1)
# ('"output_type":', 2)
# ('"outputs":', 6)
# ('"print', 1)
# ('"print_words(\'google', 1)
# ('"print_words()', 1)
# ('"pygments_lexer":', 1)
# ('"python', 1)
# ('"python",', 3)
# ('"python2"', 1)
# ('"so', 2)
# ('"source":', 6)
# ('"text/plain":', 1)
# ('"text/x-python",', 1)
# ('"the', 1)
# ('"to', 1)
# ('"traceback":', 1)
# ('"use', 1)
# ('"version":', 2)
# ('"when', 1)
# ('"word1', 1)
# ('"word2', 1)
# ('"word_count(\'google', 1)
# ('"workflow:', 1)
# ('"{\'!=\':', 1)
# ('#', 1)
# ('#lets', 1)
# ('#sorting', 1)
# ("'", 1)
# ("'#':", 1)
# ("'(no':", 1)
# ("'(python':", 1)
# ("'+':", 1)
# ("'+++your':", 1)
# ("',':", 1)
# ("'--':", 1)
# ("'--count':", 1)
# ('\'--count\':\\n",', 1)
# ("'--topcount':", 1)
# ('\'--topcount\':\\n",', 1)
# ("'--topcount}':", 1)
# ('\'-tt\\\\\\\\n\\",\':', 1)
# ("'./wordcount.py':", 1)
# ("'2':", 1)
# ('\'2.0\\\\\\\\n\\",\':', 1)
# ("'20':", 1)
# ("'2010':", 1)
# ('\'2\\",\':', 1)
# ('\'3:\\\\\\\\n\\",\':', 1)
# ("'4,':", 1)
# ("'9,':", 1)
# ("'=':", 1)
# ("'==':", 1)
# ("'[':", 1)
# ("'[],':", 1)
# ('\'\\"#!/usr/bin/python\':', 1)
# ('\'\\"###\\\\\\\\n\\",\':', 1)
# ('\'\\"#\':', 1)
# ('\'\\"#example\':', 1)
# ('\'\\"\':', 1)
# ('\'\\"...\\\\\\\\n\\",\':', 1)
# ('\'\\".py\\",\':', 1)
# ('\'\\"1.\':', 1)
# ('\'\\"2.\':', 1)
# ('\'\\"2.7.10\\"\':', 1)
# ('\'\\"\\\\\\\\\\"\\\\\\\\\\"\\\\\\\\\\"\\\\\\\\n\\",\':', 1)
# ('\'\\"\\\\\\\\\\"\\\\\\\\\\"\\\\\\\\\\"wordcount\':', 1)
# ('\'\\"\\\\\\\\n\\"\':', 1)
# ('\'\\"\\\\\\\\n\\",\':', 1)
# ('\'\\"and\':', 1)
# ('\'\\"cell_type\\":\':', 1)
# ('\'\\"cells\\":\':', 1)
# ('\'\\"code\\",\':', 1)
# ('\'\\"codemirror_mode\\":\':', 1)
# ('\'\\"come\':', 1)
# ('\'\\"def\':', 1)
# ('\'\\"display_name\\":\':', 1)
# ('\'\\"execution_count\\":\':', 1)
# ('\'\\"file_extension\\":\':', 1)
# ('\'\\"google\\\\\'s\':', 1)
# ('\'\\"how\':', 1)
# ('\'\\"if\':', 1)
# ('\'\\"import\':', 1)
# ('\'\\"ipython2\\",\':', 1)
# ('\'\\"ipython\\",\':', 1)
# ('\'\\"kernelspec\\":\':', 1)
# ('\'\\"language\\":\':', 1)
# ('\'\\"language_info\\":\':', 1)
# ('\'\\"metadata\\":\':', 1)
# ('\'\\"milestone\':', 1)
# ('\'\\"mimetype\\":\':', 1)
# ('\'\\"name\\":\':', 1)
# ('\'\\"nbconvert_exporter\\":\':', 1)
# ('\'\\"nbformat\\":\':', 1)
# ('\'\\"nbformat_minor\\":\':', 1)
# ('\'\\"optional:\':', 1)
# ('\'\\"outputs\\":\':', 1)
# ('\'\\"print\':', 1)
# ('\'\\"print_words()\':', 1)
# ('\'\\"pygments_lexer\\":\':', 1)
# ('\'\\"python\':', 1)
# ('\'\\"python2\\"\':', 1)
# ('\'\\"python\\",\':', 1)
# ('\'\\"so\':', 1)
# ('\'\\"source\\":\':', 1)
# ('\'\\"text/x-python\\",\':', 1)
# ('\'\\"the\':', 1)
# ('\'\\"to\':', 1)
# ('\'\\"use\':', 1)
# ('\'\\"version\\":\':', 1)
# ('\'\\"when\':', 1)
# ('\'\\"word1\':', 1)
# ('\'\\"word2\':', 1)
# ('\'\\"word_count(\\\\\'google\':', 1)
# ('\'\\"workflow:\':', 1)
# ('\'\\\\\'--count\\\\\':\\\\\\\\n\\",\':', 1)
# ('\'\\\\\'--topcount\\\\\':\\\\\\\\n\\",\':', 1)
# ('\'\\\\\'__main__\\\\\':\\\\\\\\n\\",\':', 1)
# ('\'\\\\\'r\\\\\')\\\\\\\\n\\",\':', 1)
# ('\'\\\\\\\\n\\",\':', 1)
# ("']':", 1)
# ("'],':", 1)
# ('\'__main__\':\\n",', 1)
# ("'__name__':", 1)
# ("'a':", 1)
# ("'above':", 1)
# ("'all':", 1)
# ("'already':", 1)
# ("'an':", 1)
# ("'and':", 1)
# ('\'and\\\\\\\\n\\",\':', 1)
# ("'apache':", 1)
# ("'appears':", 1)
# ("'are':", 1)
# ("'argument':", 1)
# ("'arguments)':", 1)
# ("'as':", 1)
# ("'at':", 1)
# ("'avoid':", 1)
# ("'basic':", 1)
# ("'before':", 1)
# ("'below':", 1)
# ("'build':", 1)
# ("'builds':", 1)
# ("'but':", 1)
# ("'by':", 1)
# ("'call':", 1)
# ("'calls':", 1)
# ("'can':", 1)
# ('\'class\\\\\\\\n\\",\':', 1)
# ("'code':", 1)
# ("'command':", 1)
# ("'common':", 1)
# ("'common,':", 1)
# ("'complete.':", 1)
# ("'copyright':", 1)
# ("'could':", 1)
# ("'count':", 1)
# ('\'count1\\\\\\\\n\\",\':', 1)
# ('\'count2\\\\\\\\n\\",\':', 1)
# ('\'counts\\\\\\\\n\\",\':', 1)
# ("'course':", 1)
# ("'data':", 1)
# ("'define':", 1)
# ('\'define.\\\\\\\\n\\",\':', 1)
# ("'defined':", 1)
# ("'dict':", 1)
# ("'dictionary':", 1)
# ("'duplication':", 1)
# ("'each':", 1)
# ("'elif':", 1)
# ("'else:':", 1)
# ('\'else:\\\\\\\\n\\",\':', 1)
# ('\'exercise.ip\\\\\')\\"\':', 1)
# ('\'exercise\\\\\\\\n\\",\':', 1)
# ('\'file\\\\\'\\\\\\\\n\\",\':', 1)
# ('\'file\\\\\\\\n\\",\':', 1)
# ("'file_input':", 1)
# ('\'file_input:\\\\\\\\n\\",\':', 1)
# ("'filename':", 1)
# ("'fine).':", 1)
# ("'first,':", 1)
# ("'flag,':", 1)
# ("'for':", 1)
# ("'function':", 1)
# ('\'function.\\\\\\\\n\\",\':', 1)
# ("'functions':", 1)
# ('\'functions.\\\\\\\\n\\",\':', 1)
# ("'get':", 1)
# ("'google':", 1)
# ("'helper':", 1)
# ('\'here+++\\\\\\\\n\\",\':', 1)
# ('\'http://code.google.com/edu/languages/google-python-class/\\\\\\\\n\\",\':', 1)
# ('\'http://www.apache.org/licenses/license-2.0\\\\\\\\n\\",\':', 1)
# ("'if':", 1)
# ("'implement':", 1)
# ("'in':", 1)
# ('\'inc.\\\\\\\\n\\",\':', 1)
# ('\'inside\\\\\\\\n\\",\':', 1)
# ('\'intermediate\\\\\\\\n\\",\':', 1)
# ("'is':", 1)
# ("'it':", 1)
# ('\'it.\\\\\\\\n\\",\':', 1)
# ("'just':", 1)
# ("'keys':", 1)
# ("'len(sys.argv)':", 1)
# ("'letters':", 1)
# ("'license,':", 1)
# ("'licensed':", 1)
# ("'line':", 1)
# ("'list':", 1)
# ('\'lowercase,\\\\\\\\n\\",\':', 1)
# ("'main()':", 1)
# ('\'main():\\\\\\\\n\\",\':', 1)
# ('\'main()\\\\\\\\n\\",\':', 1)
# ('\'milestone.\\\\\\\\n\\",\':', 1)
# ("'most':", 1)
# ("'must':", 1)
# ("'next':", 1)
# ("'not':", 1)
# ("'null,':", 1)
# ("'often':", 1)
# ("'on':", 1)
# ('\'on.\\\\\\\\n\\",\':', 1)
# ("'once.':", 1)
# ("'open(filename,':", 1)
# ("'option':", 1)
# ("'option:':", 1)
# ('\'option\\\\\\\\n\\",\':', 1)
# ("'order':", 1)
# ("'parsing':", 1)
# ("'print':", 1)
# ("'print_top()':", 1)
# ('\'print_top().\\\\\\\\n\\",\':', 1)
# ("'print_top(filename)':", 1)
# ('\'print_top(filename)\\\\\\\\n\\",\':', 1)
# ("'print_words()':", 1)
# ('\'print_words()\\\\\\\\n\\",\':', 1)
# ("'print_words(filename)':", 1)
# ('\'print_words(filename)\\\\\\\\n\\",\':', 1)
# ("'prints':", 1)
# ('\'prints:\\\\\\\\n\\",\':', 1)
# ("'program':", 1)
# ("'provided':", 1)
# ("'punctuation':", 1)
# ("'python':", 1)
# ('\'r\')\\n",', 1)
# ("'reads':", 1)
# ("'return':", 1)
# ("'returns':", 1)
# ("'same':", 1)
# ('\'similar\\\\\\\\n\\",\':', 1)
# ("'so':", 1)
# ("'sort':", 1)
# ("'sorted':", 1)
# ('\'sorted\\\\\\\\n\\",\':', 1)
# ("'split':", 1)
# ("'store':", 1)
# ("'str.split()':", 1)
# ("'structure':", 1)
# ('\'sys.argv[1]\\\\\\\\n\\",\':', 1)
# ('\'sys.argv[2]\\\\\\\\n\\",\':', 1)
# ('\'sys.exit(0).\\\\\\\\n\\",\':', 1)
# ('\'sys.exit(1)\\\\\\\\n\\",\':', 1)
# ('\'sys\\\\\\\\n\\",\':', 1)
# ("'text':", 1)
# ("'that':", 1)
# ("'the'", 2)
# ("'the':", 1)
# ("'their':", 1)
# ("'then':", 1)
# ("'this':", 1)
# ("'to':", 1)
# ('\'to\\\\\\\\n\\",\':', 1)
# ("'top':", 1)
# ("'try':", 1)
# ("'under':", 1)
# ("'unknown", 1)
# ("'usage:", 1)
# ("'utility':", 1)
# ("'values':", 1)
# ("'version':", 1)
# ("'which':", 1)
# ('\'whitespace.\\\\\\\\n\\",\':', 1)
# ("'whole':", 1)
# ("'will':", 1)
# ("'word':", 1)
# ('\'word.\\\\\\\\n\\",\':', 1)
# ("'word/count':", 1)
# ('\'word=lower.word()\\\\\\\\n\\",\':', 1)
# ('\'word_count(filename):\\\\\\\\n\\",\':', 1)
# ("'word_count_d'", 2)
# ("'word_counts_d':", 1)
# ('\'word_counts_d:\\\\\\\\n\\",\':', 1)
# ("'word_counts_d={}':", 1)
# ('\'word_counts_d[word]+=1\\\\\\\\n\\",\':', 1)
# ('\'word_counts_d[word]=1\\\\\\\\n\\",\':', 1)
# ('\'word_counts_d\\"\':', 1)
# ("'wordcount':", 1)
# ("'words':", 1)
# ("'words,':", 1)
# ('\'words:\\\\\\\\n\\",\':', 1)
# ('\'words=line.split()\\\\\\\\n\\",\':', 1)
# ("'working,':", 1)
# ("'write':", 1)
# ('\'write.\\\\\\\\n\\",\':', 1)
# ("'you':", 1)
# ("'your':", 1)
# ("'{':", 1)
# ("'{--count':", 1)
# ("'{},':", 1)
# ("'|':", 1)
# ("'}':", 1)
# ("'},':", 1)
# ('(most', 1)
# ('(no', 1)
# ('(python', 1)
# ('+', 1)
# ('+++your', 1)
# (',', 1)
# ('--', 1)
# ('--count', 1)
# ('--topcount', 1)
# ('--topcount}', 1)
# ('-tt\\n",', 1)
# ('./wordcount.py', 1)
# ('1,\\n",', 215)
# ('11,', 1)
# ('12,', 2)
# ('12,\\n",', 2)
# ('14,\\n",', 1)
# ('16,\\n",', 1)
# ('1\\u001b', 2)
# ('2', 2)
# ('2",', 1)
# ('2,\\n",', 31)
# ('2.0\\n",', 1)
# ('20', 1)
# ('20,', 1)
# ('2010', 1)
# ('21,', 1)
# ('24,\\n",', 1)
# ('2\\u001b', 2)
# ('3,\\n",', 24)
# ('3:\\n",', 1)
# ('3\\u001b', 1)
# ('4,', 1)
# ('4,\\n",', 3)
# ('4\\u001b', 1)
# ('5,\\n",', 3)
# ('5\\u001b', 1)
# ('5}"', 1)
# ('6,\\n",', 1)
# ('7,\\n",', 1)
# ('8,\\n",', 1)
# ('=', 3)
# ('==', 3)
# ('[', 10)
# ('[]', 1)
# ('[],', 4)
# ('\\"\'\\":', 1)
# ('\\"\'the\'\\":', 1)
# ('\\"\'unknown\\":', 1)
# ('\\"\'usage:\\":', 1)
# ('\\"don\'t\\":', 1)
# ('\\"google\'s\\":', 1)
# ('\\"that\'s\\":', 1)
# ('\\n",', 4)
# ('\\u001b#example\\u001b\\u001b\\u001b\\u001b\\u001b\\u001b\\n\\u001b---->', 1)
# ('\\u001b#sorting', 1)
# ('\\u001bdef\\u001b', 1)
# ('\\u001bfor\\u001b', 1)
# ('\\u001bin\\u001b', 1)
# ('\\u001bprint\\u001b\\u001b(\\u001b\\u001bword\\u001b\\u001b,\\u001b\\u001bwords_dict\\u001b\\u001b[\\u001b\\u001bword\\u001b\\u001b[0;34m]\\u001b\\u001b)\\u001b\\u001b\\u001b\\u001b\\n",', 1)
# ('\\u001b<module>\\u001b()\\u001b\\n\\u001b', 1)
# ('\\u001bprint_words\\u001b(filename)\\u001b\\n\\u001b', 1)
# ("\\u001bprint_words\\u001b\\u001b(\\u001b\\u001b'google", 1)
# ('\\u001bprint_words\\u001b\\u001b(\\u001b\\u001bfilename\\u001b\\u001b)\\u001b\\u001b:\\u001b\\u001b\\u001b\\u001b\\n\\u001b---->', 1)
# ('\\u001bword\\u001b', 1)
# ('\\u001bword_count_d\\u001b\\u001b(\\u001b\\u001bfilename\\u001b\\u001b)\\u001b', 1)
# ('\\u001bwords\\u001b\\u001b:\\u001b\\u001b\\u001b\\u001b\\n\\u001b', 1)
# ('\\u001bwords\\u001b\\u001b=\\u001b\\u001bsorted\\u001b\\u001b(\\u001b\\u001bwords_dict\\u001b\\u001b.\\u001b\\u001bkeys\\u001b\\u001b(\\u001b\\u001b)\\u001b\\u001b)\\u001b\\u001b\\u001b\\u001b\\n\\u001b', 1)
# ('\\u001bwords_dict\\u001b\\u001b=\\u001b', 1)
# (']', 7)
# ('],', 3)
# ('__name__', 1)
# ('a', 8)
# ('above', 1)
# ('all', 2)
# ('already', 1)
# ('an', 1)
# ('and', 12)
# ('and\\n",', 1)
# ('apache', 1)
# ('appears', 1)
# ('are', 4)
# ('argument', 1)
# ('arguments)', 1)
# ('as', 2)
# ('at', 1)
# ('avoid', 1)
# ('basic', 1)
# ('before', 1)
# ('below', 1)
# ('build', 1)
# ('builds', 1)
# ('but', 1)
# ('by', 1)
# ('call', 2)
# ('calls', 2)
# ('can', 1)
# ('class\\n",', 2)
# ('code', 3)
# ('command', 1)
# ('common', 2)
# ('common,', 1)
# ('complete.', 1)
# ('copyright', 1)
# ('could', 1)
# ('count', 1)
# ('count1\\n",', 1)
# ('count2\\n",', 1)
# ('counts..', 1)
# ('counts\\n",', 2)
# ('course', 3)
# ('data', 1)
# ('define', 2)
# ('define.\\n",', 1)
# ('defined', 1)
# ('defined"', 1)
# ('defined",', 1)
# ('dict', 1)
# ('dictionary', 2)
# ("don't", 1)
# ('duplication', 1)
# ('each', 1)
# ('elif', 1)
# ('else:', 1)
# ('else:\\n",', 1)
# ('exercise.ipynb\')"', 2)
# ('exercise.ipynb\'\\u001b\\u001b)\\u001b\\u001b\\u001b\\u001b\\n\\u001b",', 1)
# ('exercise\\n",', 1)
# ('file\'\\n",', 1)
# ('file\\n",', 1)
# ('file_input', 1)
# ('file_input:\\n",', 1)
# ('filename', 1)
# ('fine).', 1)
# ('first,', 1)
# ('flag,', 2)
# ('for', 8)
# ('function', 3)
# ('function.\\n",', 1)
# ('functions', 2)
# ('functions.\\n",', 1)
# ('get', 1)
# ('global', 1)
# ('google', 1)
# ("google's", 1)
# ('helper', 2)
# ('here+++\\n",', 1)
# ('http://code.google.com/edu/languages/google-python-class/\\n",', 1)
# ('http://www.apache.org/licenses/license-2.0\\n",', 1)
# ('if', 3)
# ('implement', 2)
# ('in', 8)
# ('inc.\\n",', 1)
# ('inside\\n",', 1)
# ('intermediate\\n",', 1)
# ('is', 7)
# ('it', 2)
# ('it.\\n",', 1)
# ('just', 2)
# ('keys', 3)
# ('last)",', 1)
# ('len(sys.argv)', 1)
# ('letters', 1)
# ('license,', 1)
# ('licensed', 1)
# ('line', 2)
# ('list', 1)
# ('lowercase,\\n",', 1)
# ('main()', 1)
# ('main():\\n",', 1)
# ('main()\\n",', 1)
# ('make', 1)
# ('milestone.\\n",', 1)
# ('most', 3)
# ('must', 1)
# ('name', 2)
# ('next', 2)
# ('not', 3)
# ('now', 1)
# ('null,', 2)
# ('of', 1)
# ('often', 1)
# ('on', 1)
# ('on.\\n",', 1)
# ('once.', 1)
# ('open(filename,', 1)
# ('option', 3)
# ('option:', 1)
# ('option\\n",', 1)
# ('order', 1)
# ('parsing', 1)
# ('print', 3)
# ('print(word,words_dict[word])"', 1)
# ('print_top()', 3)
# ('print_top().\\n",', 1)
# ('print_top(filename)', 2)
# ('print_top(filename)\\n",', 1)
# ('print_words()', 3)
# ('print_words()\\n",', 1)
# ('print_words(filename)', 2)
# ('print_words(filename):\\n",', 1)
# ('print_words(filename)\\n",', 1)
# ('prints', 1)
# ('prints:\\n",', 1)
# ('program', 1)
# ('provided', 1)
# ('punctuation', 1)
# ('python', 5)
# ('reads', 1)
# ('recent', 1)
# ('return', 1)
# ('returns', 1)
# ('same', 1)
# ('similar\\n",', 1)
# ('so', 1)
# ('sort', 1)
# ('sorted', 1)
# ('sorted\\n",', 1)
# ('split', 1)
# ('store', 1)
# ('str.split()', 1)
# ('structure', 1)
# ('sys.argv[1]\\n",', 1)
# ('sys.argv[2]\\n",', 1)
# ('sys.exit(0).\\n",', 1)
# ('sys.exit(1)\\n",', 2)
# ('sys\\n",', 1)
# ('text', 1)
# ('that', 2)
# ("that's", 2)
# ('the', 14)
# ('their', 2)
# ('then', 2)
# ('this', 1)
# ('to', 3)
# ('to\\n",', 1)
# ('top', 1)
# ('traceback', 1)
# ('try', 1)
# ('under', 1)
# ('unsorted', 1)
# ('utility', 2)
# ('values', 1)
# ('version', 1)
# ('which', 6)
# ('whitespace.\\n",', 1)
# ('whole', 1)
# ('will', 1)
# ('with', 1)
# ('word', 6)
# ('word.\\n",', 1)
# ('word/count', 1)
# ('word=word.lower()\\n",', 1)
# ('word_count_d(filename)', 1)
# ('word_count_d(filename):', 1)
# ('word_counts_d', 1)
# ('word_counts_d"', 1)
# ('word_counts_d:\\n",', 1)
# ('word_counts_d={}', 1)
# ('word_counts_d[word]+=1\\n",', 1)
# ('word_counts_d[word]=1\\n",', 1)
# ('wordcount', 3)
# ('words', 4)
# ('words,', 1)
# ('words:\\n",', 2)
# ('words=line.split()\\n",', 1)
# ('words=sorted(words_dict.keys())\\n",', 1)
# ('words\\u001b\\u001b\\u001b\\u001b\\n\\u001b\\u001b', 1)
# ('words_dict=', 1)
# ('working,', 1)
# ('write', 1)
# ('write.\\n",', 1)
# ('you', 3)
# ('your', 1)
# ('{', 14)
# ('{--count', 1)
# ('{},', 7)
# ('|', 1)
# ('}', 5)
# ('},', 9)

# %%
def WordCounterPerItem(word):
  return word[1]

# %%
def print_top(filename):
  words_dict= word_count_d(filename) #Sorting keys which are words 
  words=sorted(words_dict.items(),key=WordCounterPerItem, reverse=True)
  for word in words[:20]:
    print (word[0], word[1])

# %%
#Example
print_top('Google Python Course WordCount Exercise.ipynb')
# Out:
# ('"', 680)
# ('1,\\n",', 556)
# ('1)\\n",', 556)
# ('2,\\n",', 39)
# ('2)\\n",', 39)
# ('3,\\n",', 22)
# ('3)\\n",', 22)
# ('{', 20)
# ('"\\n",', 16)
# ('[', 15)
# ('the', 14)
# ('},', 14)
# ('"metadata":', 13)
# ('"execution_count":', 12)
# ('"#', 12)
# ('{},', 12)
# ('and', 12)
# (']', 11)
# ('"code",', 11)
# ('"cell_type":', 11)
